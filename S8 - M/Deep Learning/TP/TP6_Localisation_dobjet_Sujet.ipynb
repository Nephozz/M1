# %% [markdown]
# # Localisation et détection d'objet
#
# Dans ce TP, nous allons mettre en pratique certaines des méthodes présentées en cours pour localiser des objets dans une image.
#
# En localisation et détection, on cherche à déterminer la position d'un objet, ainsi que sa classe, sous la forme d'une boîte englobante de largeur $b_w$ et hauteur $b_h$, et dont le centre a pour coordonnées le point $(b_x, b_y)$.
#
# <center> <img src="https://drive.google.com/uc?id=1_jHHv6ZDe-3Xz25jIZ6o177laBEfmMRR" style="width:500;height:300px;"></center>
# <caption><center> Figure 1: Modèle de boîte englobante utilisé pour la localisation </center></caption>
#
# Le problème de localisation considère qu'un seul objet est présent sur l'image, alors que le problème de détection cherche à déterminer l'ensemble des objets présents sur l'image.
#
#
#
# Pour commencer, récupérez les images de la base de données :

# %%
# !git clone https://github.com/axelcarlier/mangeoires_loc.git
# Out:
# Cloning into 'mangeoires_loc'...
# remote: Enumerating objects: 2333, done.
# remote: Total 2333 (delta 0), reused 0 (delta 0), pack-reused 2333
# Receiving objects: 100% (2333/2333), 48.39 MiB | 26.26 MiB/s, done.

# %% [markdown]
# La base de données consiste en des photographies prises par une caméra reliée à une Raspberry Pi, cachée dans une mangeoire. Plusieurs mangeoires sont disséminées dans la nature en Occitanie, et l'objectif de [ce projet](https://econect.cnrs.fr/) est la reconnaissance des espèces et le comptage des individus qui viennent se poser devant le caméra, afin de suivre l'évolution des populations d'oiseaux et ainsi monitorer la biodiversité.
#
# La base de données qui vous est fournie regroupe 11 espèces d'animaux, majoritairement des oiseaux, désignés par un code :
#
# 1. Mésange charbonnière (**MESCHA**)
# 2. Verdier d'Europe (**VEREUR**)
# 3. Écureuil roux (**ECUROU**)
# 4. Pie bavarde (**PIEBAV**)
# 5. Sittelle torchepot (**SITTOR**)
# 6. Pinson des arbres (**PINARB**)
# 7. Mésange noire (**MESNOI**)
# 8. Mésange nonnette (**MESNON**)
# 9. Mésange bleue (**MESBLE**)
# 10. Rouge-gorge (**ROUGOR**)
# 11. Accenteur mouchet (**ACCMOU**)
#
#
#
# <center> <img src="https://drive.google.com/uc?id=1Eit86N4D0Ea7ai1rBa0o-GmTwckhP9i0" width=200>
# <img src="https://drive.google.com/uc?id=1lC7WL93UqDT_KV2m21yx99N5dkf98nCY" width=200>
# <img src="https://drive.google.com/uc?id=10tzJORcSrSckDWmBDBtc8FUirxdbRxri" width=200>
# <img src="https://drive.google.com/uc?id=1IHZp_B6bc8bADtAReRHhcyOjDQZAXDBQ" width=200></center>
# <caption><center> Figure 2: Exemples d'images de la base de données </center></caption>

# %% [markdown]
# # Localisation et classification d'objet
#
# Dans cette partie, nous allons nous concentrer sur le problème de la localisation d'un seul objet par classe. La base de données a été épurée pour se concentrer uniquement sur ce cas.

# %%
import PIL
from PIL import Image
import csv
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# %% [markdown]
# ## Préparation des données
#
# Le code ci-dessous permet de charger les données et les formater pour la classification. Prenez le temps de regarder un peu le format des labels $y$.
# Notez que les images sont rendues carrées lors du chargement.

# %%
# Lecture du CSV contenant les informations relatives à la base de données
dataset = []
with open('mangeoires_loc/bd_mangeoires_equilibre.csv', newline='') as csvfile:
	filereader = csv.reader(csvfile, delimiter=' ', quotechar='|')
	for row in filereader:
		data = row[0].split(',')
		if data[0] != 'Data':
			box = [float(data[5]), float(data[6]), float(data[7]), float(data[8])]
			new_entry = {'type': data[0], 'specie': data[1], 'path': data[2], 'shape': [float(data[3]), float(data[4])], 'box': box}
			dataset.append(new_entry)

# Nombre de classes de la base de données et intitulé des classes
class_labels = list(dict.fromkeys([item['specie'] for item in dataset]))
num_classes = len(class_labels)

# Extraction des données d'apprentissage et de test
dataset_train = [item for item in dataset if item['type']=='TRAIN']
dataset_test = [item for item in dataset if item['type']=='TEST']

print(class_labels)
# Out:
# ['MESCHA', 'VEREUR', 'ECUROU', 'PIEBAV', 'SITTOR', 'PINARB', 'MESNOI', 'MESNON', 'MESBLE', 'ROUGOR', 'ACCMOU']

# %%
def build_localization_tensors(image_size, dataset, num_classes):
  # Préparation des structures de données pour x et y
  x = np.zeros((len(dataset), image_size, image_size, 3))
  y = np.empty((len(dataset), num_classes + 5)) # 1 + 4 + num_classes : présence / boîte englobante / classes

  # Compteur de parcours du dataset
  i = 0

  for item in dataset:
    # Lecture de l'image
    img = Image.open('mangeoires_loc/' + item['path'])
    # Mise à l'échelle de l'image
    img = img.resize((image_size,image_size), Image.ANTIALIAS)
    # Remplissage de la variable x
    x[i] = np.asarray(img)

    y[i, 0] = 1 # Un objet est toujours présent !

    # Coordonnées de boîte englobante
    img_shape = item['shape']
    box = item['box']
    bx = (box[0] + (box[2] - box[0])/2)/img_shape[0]
    by = (box[1] + (box[3] - box[1])/2)/img_shape[1]
    bw = (box[2] - box[0])/img_shape[0]
    bh = (box[3] - box[1])/img_shape[1]
    y[i, 1] = bx
    y[i, 2] = by
    y[i, 3] = bw
    y[i, 4] = bh

    # Probabilités de classe, sous la forme d'une one-hot vector
    label = class_labels.index(item['specie'])
    classes_probabilities = keras.utils.to_categorical(label, num_classes=num_classes)
    y[i, 5:] = classes_probabilities

    i = i+1

  return x, y

# %% [markdown]
# Séparation des données d'entraînement pour extraire un ensemble de validation, et pré-traitement des données.

# %%
from sklearn.model_selection import train_test_split


# Pour la suite du TP on considèrera des images de taille 64x64x3
# Augmenter cette valeur donnerait de meilleurs résultats mais nécessiterait des calculs plus long.
IMAGE_SIZE = 64

# Lecture des données d'entraînement et de test
x, y = build_localization_tensors(IMAGE_SIZE, dataset_train, num_classes)
x_test, y_test = build_localization_tensors(IMAGE_SIZE, dataset_test, num_classes)

#Extraction d'un ensemble de validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.10, random_state=42)

# Pour améliorer l'entraînement, on peut centrer-réduire les coordonnées des bounding boxes...
y_std = np.std(y_train, axis=0)
y_mean = np.mean(y_train, axis=0)
y_train[...,1:5] = (y_train[...,1:5] - y_mean[1:5])/y_std[1:5]
y_val[...,1:5] = (y_val[...,1:5] - y_mean[1:5])/y_std[1:5]
y_test[...,1:5] = (y_test[...,1:5] - y_mean[1:5])/y_std[1:5]

# ... et normaliser les valeurs de couleur
x_train = x_train/255
x_val = x_val/255
x_test = x_test/255
# Out:
# <ipython-input-4-370883c70e58>:13: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((image_size,image_size), Image.ANTIALIAS)

# %% [markdown]
# ## Fonctions utiles

# %% [markdown]
# Une fonction de calcul de l'intersection sur union, qui nous sera utile pour les métriques d'évaluation de nos méthodes :
#
# $$ IoU (R_1, R_2) = \frac{\mathcal{A} (R_1 \cap R_2)}{\mathcal{A} (R_1 \cup R_2)} = \frac{\mathcal{A} (R_1 \cap R_2)}{\mathcal{A} (R_1) + \mathcal{A} (R_2) -  \mathcal{A} (R_1 \cap R_2)} $$
#
# <center>
# <img src="https://drive.google.com/uc?id=1BQx2kDOCltZ_5gcnKVWTVUVNmGk-7qBC" width=500>
# </center>

# %%
### A COMPLETER
def intersection_sur_union(box1, box2):
  """
  Calcul de l'intersection sur union entre deux rectangles box1 et box2

  Arguments:
  box1, box2 -- les coordonnées des deux rectangles, chacun sous la forme [cx, cy, w, h]
                où (cx, cy) désigne les coordonnées du centre du rectangle,
                w sa largeur et h sa hauteur

  Retourne :
  iou -- la valeur d'intersection sur union entre les deux rectangles
  """
  A_box1 = box1[3] * box1[2]
  A_box2 = box2[3] * box2[2]

  x1 = box1[0] - box1[2] / 2
  y1 = box1[1] - box1[3] / 2

  x2 = box1[0] + box1[2] / 2
  y2 = box1[1] + box1[3] / 2

  x3 = box2[0] - box2[2] / 2
  y3 = box2[1] - box2[3] / 2

  x4 = box2[0] + box2[2] / 2
  y4 = box2[1] + box2[3] / 2

  w_inter = min(x2, x4) - max(x1, x3)
  h_inter = min(y2, y4) - max(y1, y3)

  A_inter = w_inter * h_inter

  iou = A_inter / (A_box1 + A_box2 - A_inter)
  return iou

# %%
print(intersection_sur_union([2.5, 2, 1, 4], [2, 3, 4, 2]))  # Résultat attendu : 0.2
print(intersection_sur_union([2.5, 2, 1, 4], [5, 3, 4, 2]))  # Résultat attendu : 0.0
# Out:
# 0.2
# 0.0

# %% [markdown]
# Calcul des différentes métriques :
#
# $$ P = \frac{TP}{TP + FP} $$
#
# $$ R = \frac{TP}{TP + FN} $$
#
# $$ F1 = \frac{2 * P * R}{P + R} $$
#
# où $TP$ désigne le nombre de vrais positifs, $FP$ le nombre de faux positifs, $FN$ le nombre de faux négatifs, $P$ la précision, $R$ le rappel et $F1$ le F1-score.
#
# On considère souvent qu'une détection est correcte si la classification est valide et que l'intersection sur union entre vérité terrain et prédiction est supérieure à 0.5 (on utilisera un seuil modifiable *iou_thres*).

# %%
# A COMPLETER
def global_accuracy(y_true, y_pred, iou_thres=0.5):
  """
  Calcul, pour chaque classe de la précision, du rappel et du F1-score ainsi
  que du pourcentage global de bonnes détections.

  Arguments:
  y_true -- les labels de la vérité terrain, de dimension (M, 1+4+N) où M désigne
          le nombre d'éléments du dataset et N le nombre de classes (11 dans notre cas)
  y_pred -- les labels prédits par un modèle, de dimension (M, 1+4+N)
  iou_thres -- seuil d'intersection sur union entre une boîte "vérité-terrain" et
              une boite prédite au-dessus duquel on considère que la prédiction est correcte

  Retourne :
  class_res -- liste de longueur N contenant des dictionnaires sous la forme
            {"Précision": p, "Rappel": r, "F-score": f} résumant les métriques
            précision, rappel et F1-score pour chacune des classes.
  accuracy -- pourcentage global de bonnes détections
  """
  # Initialisation des métriques : nombre de vrais positifs (TP), faux positifs (FP)
  # et faux négatifs (FN) pour chaque classe
  class_metrics = []
  for i in range(num_classes):
    class_metrics.append({'TP': 0, 'FP': 0, 'FN': 0})

  # Nombres de détections correctes et de détections incorrectes
  total_correct_detections = 0
  total_incorrect_detections = 0
  for i in range(y_true.shape[0]):
    # Labels vérité-terrain et prédits
    groundtruth_label = np.argmax(y_true[i,5:])
    predicted_label = np.argmax(y_pred[i,5:])

    # Coordonnées de boîtes englobantes réelles et prédites
    bx_true = (y_true[i,1]*y_std[1] + y_mean[1])
    by_true = (y_true[i,2]*y_std[2] + y_mean[2])
    bw_true = (y_true[i,3]*y_std[3] + y_mean[3])
    bh_true = (y_true[i,4]*y_std[4] + y_mean[4])
    bx_pred = (y_pred[i,1]*y_std[1] + y_mean[1])
    by_pred = (y_pred[i,2]*y_std[2] + y_mean[2])
    bw_pred = (y_pred[i,3]*y_std[3] + y_mean[3])
    bh_pred = (y_pred[i,4]*y_std[4] + y_mean[4])

    # Calcul de l'intersection sur union
    iou = intersection_sur_union([bx_true, by_true, bw_true, bh_true], [bx_pred, by_pred, bw_pred, bh_pred])

    ### A COMPLETER
    # Si la détection est correcte :
    if groundtruth_label == predicted_label and iou > iou_thres:
      class_metrics[predicted_label]['TP'] += 1
      total_correct_detections += 1
    else:
      class_metrics[predicted_label]['FP'] += 1
      class_metrics[groundtruth_label]['FN'] += 1
      total_incorrect_detections += 1

  class_res = []
  for i in range(num_classes):
    if class_metrics[i]['TP'] + class_metrics[i]['FP'] != 0:
      P = class_metrics[i]['TP'] / (class_metrics[i]['TP'] + class_metrics[i]['FP'])
    else:
      P = 0
    if class_metrics[i]['TP'] + class_metrics[i]['FP'] != 0:
      R = class_metrics[i]['TP'] / (class_metrics[i]['TP'] + class_metrics[i]['FN'])
    else:
      R = 0
    if P + R != 0:
      F_score = (2 * P * R) / (P + R)
    else:
      F_score = 0
    class_res.append({'Precision': P, 'Rappel': R, 'F-score': F_score})

  accuracy = total_correct_detections / (total_incorrect_detections + total_correct_detections) * 100
  ### FIN
  return class_res, accuracy

# %%
num_class_test = 3
class_labels_test = ['Classe 1', 'Classe 2', 'Classe 3']
y_true_test = np.ones((num_class_test,8))
y_true_test[0,:2] = [0.5, 0.5]
y_true_test[0, 5:] = [1, 0, 0]
y_true_test[1,:2] = [0.5, 0.5]
y_true_test[1, 5:] = [0, 1, 0]
y_true_test[2,:2] = [0.5, 0.5]
y_true_test[2, 5:] = [0, 0, 1]
y_pred_test = np.ones((num_class_test,8))
y_pred_test[0,:2] = [0.6, 0.6]
y_pred_test[0, 5:] = [1, 0, 0]
y_pred_test[1,:2] = [2.5, 2.5]
y_pred_test[1, 5:] = [0, 0, 1]
y_pred_test[2,:2] = [0.6, 0.6]
y_pred_test[2, 5:] = [0, 0, 1]

class_res_test, acc_test = global_accuracy(y_true_test, y_pred_test)

print(f"La précision globale est de {acc_test:.1f}%")

print()
print("--------------------------------------------")
print("|  Classe  | Précision | Rappel | F1-score |")
print("--------------------------------------------")
for i in range(num_class_test):
  print(f"| {class_labels_test[i]:9s}|   {class_res_test[i]['Precision']:.2f}    |  {class_res_test[i]['Rappel']:.2f}  |   {class_res_test[i]['F-score']:.2f}   |")
  print("--------------------------------------------")
# Out:
# La précision globale est de 66.7%
#
# --------------------------------------------
# |  Classe  | Précision | Rappel | F1-score |
# --------------------------------------------
# | Classe 1 |   1.00    |  1.00  |   1.00   |
# --------------------------------------------
# | Classe 2 |   0.00    |  0.00  |   0.00   |
# --------------------------------------------
# | Classe 3 |   0.50    |  1.00  |   0.67   |
# --------------------------------------------

# %% [markdown]
# **Affichage attendu :**
# ```
# La précision globale est de 66.7%
#
# --------------------------------------------
# |  Classe  | Précision | Rappel | F1-score |
# --------------------------------------------
# | Classe 1 |   1.00    |  1.00  |   1.00   |
# --------------------------------------------
# | Classe 2 |   0.00    |  0.00  |   0.00   |
# --------------------------------------------
# | Classe 3 |   0.50    |  1.00  |   0.67   |
# --------------------------------------------
# ```

# %% [markdown]
# La fonction ci-dessous permet de calculer l'intersection sur union  sur des tenseurs (et non des tableaux numpy), elle sera donc utilisable comme métrique pendant l'entraînement.

# %%
def compute_iou(y_true, y_pred):
  ### "Dénormalisation" des coordonnées des boîtes englobantes
  pred_box_xy = y_pred[..., 0:2]* y_std[0:2] + y_mean[0:2]
  true_box_xy = y_true[..., 0:2]* y_std[0:2] + y_mean[0:2]

  ### "Dénormalisation" des largeur et hauteur des boîtes englobantes
  pred_box_wh = y_pred[..., 2:4] * y_std[2:4] + y_mean[2:4]
  true_box_wh = y_true[..., 2:4] * y_std[2:4] + y_mean[2:4]

  # Calcul des coordonnées minimales et maximales des boiptes englobantes réelles
  true_wh_half = true_box_wh / 2.
  true_mins    = true_box_xy - true_wh_half
  true_maxes   = true_box_xy + true_wh_half

  # Calcul des coordonnées minimales et maximales des boiptes englobantes prédites
  pred_wh_half = pred_box_wh / 2.
  pred_mins    = pred_box_xy - pred_wh_half
  pred_maxes   = pred_box_xy + pred_wh_half

  # Détermination de l'intersection des boîtes englobantes
  intersect_mins  = tf.maximum(pred_mins,  true_mins)
  intersect_maxes = tf.minimum(pred_maxes, true_maxes)
  intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
  intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]

  # Aire des boîtes englobantes prédites et réelles
  true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
  pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

  # Aire de l'union des boîtes prédites et réelles
  union_areas = pred_areas + true_areas - intersect_areas

  iou_scores  = tf.truediv(intersect_areas, union_areas)
  return iou_scores

def iou():
  def iou_metrics(y_true, y_pred):
    return compute_iou(y_true, y_pred)
  iou_metrics.__name__= "IoU"
  return iou_metrics

# %% [markdown]
# Visualisation des données et labels

# %%
# Si seuls x et y sont indiqués, on tire au hasard un numéro d'image et on affiche le label y associé  à l'image
# Si un 2e y, nommé y_pred, est indiqué, alors les deux labels sont affichés côte à côte, afin de pouvoir les comparer
# Enfin on peut également indiquer l'id de l'image que l'on souhaite visualiser.
def print_data_localisation(x, y, y_pred=[], id=None, image_size=64):
  if id==None:
    # Tirage aléatoire d'une image dans la base
    num_img = np.random.randint(x.shape[0]-1)
  else:
    num_img = id

  img = x[num_img]
  lab = y[num_img]

  colors = ["blue", "yellow", "red", "orange", "coral", "gold", "ivory", "fuchsia", "purple", "cyan", "navy"] # Différentes couleurs pour les différentes classes
  classes = ['MESCHA', 'VEREUR', 'ECUROU', 'PIEBAV', 'SITTOR', 'PINARB', 'MESNOI', 'MESNON', 'MESBLE', 'ROUGOR', 'ACCMOU']

  if np.any(y_pred):
    plt.subplot(1, 2, 1)

  # Affichage de l'image
  plt.imshow(img)
  # Détermination de la classe
  class_id = np.argmax(lab[5:])

  # Détermination des coordonnées de la boîte englobante dans le repère image
  ax = (lab[1]*y_std[1] + y_mean[1]) * image_size
  ay = (lab[2]*y_std[2] + y_mean[2]) * image_size
  width = (lab[3]*y_std[3] + y_mean[3]) * image_size
  height = (lab[4]*y_std[4] + y_mean[4]) * image_size
  #print("x: {}, y: {}, w: {}, h:{}".format(ax,ay,width, height))
  # Détermination des extrema de la boîte englobante
  p_x = [ax-width/2, ax+width/2]
  p_y = [ay-height/2, ay+height/2]
  # Affichage de la boîte englobante, dans la bonne couleur
  plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
  plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
  plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
  plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id])
  plt.title("Vérité Terrain : Image {} - {}".format(num_img, classes[class_id]))

  if np.any(y_pred):
    plt.subplot(1, 2, 2)
    # Affichage de l'image
    plt.imshow(img)
    lab = y_pred[num_img]
    # Détermination de la classe
    class_id = np.argmax(lab[5:])

    # Détermination des coordonnées de la boîte englobante dans le repère image
    ax = (lab[1]*y_std[1] + y_mean[1]) * image_size
    ay = (lab[2]*y_std[2] + y_mean[2]) * image_size
    width = (lab[3]*y_std[3] + y_mean[3]) * image_size
    height = (lab[4]*y_std[4] + y_mean[4]) * image_size
    #print("x: {}, y: {}, w: {}, h:{}".format(ax,ay,width, height))
    # Détermination des extrema de la boîte englobante
    p_x = [ax-width/2, ax+width/2]
    p_y = [ay-height/2, ay+height/2]
    # Affichage de la boîte englobante, dans la bonne couleur
    plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
    plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
    plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
    plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id])
    plt.title("Prédiction : Image {} - {}".format(num_img, classes[class_id]))

  plt.show()

for i in range(10):#x.shape[0]):
    print_data_localisation(x_train, y_train, image_size=IMAGE_SIZE, id=i)

# %% [markdown]
# Fonction d'affichage des courbes d'apprentissage et de validation

# %%
def plot_training_analysis(history, metric='loss'):

  loss = history.history[metric]
  val_loss = history.history['val_' + metric]

  epochs = range(len(loss))

  plt.plot(epochs, loss, 'b', linestyle="--",label='Training ' + metric)
  plt.plot(epochs, val_loss, 'g', label='Validation ' + metric)
  plt.title('Training and validation ' + metric)
  plt.legend()

  plt.show()

# %% [markdown]
# ## Travail à faire

# %% [markdown]
# <center> <img src="https://drive.google.com/uc?id=1YzCZe4pgnjJDVGklAaCHZ7HhlPJsadg9" width=500></center>
# <caption><center> Figure 3: Illustration de l'architecture du réseau à construire.  </center></caption>
#
# Complétez les codes qui vous sont fournis pour obtenir un algorithme de localisation.
# Vous pouvez utiliser n'importe quelle base convolutive de votre choix (**commencez par exemple par réutiliser celle que vous avez implémenté au TP3**), en revanche vous devrez porter une attention particulière à la couche de sortie.
#
# Vous allez en fait produire 3 sorties différentes : une caractérisant la présence d'un objet, une autre fournissant les coordonnées de la boîte englobante, et enfin une dernière effectuant la classification.

# %%
def create_model_localisation(input_shape=(64, 64, 3)):

  input_layer = Input(shape=input_shape)

  conv1 = Conv2D(32,3,activation='relu')(input_layer)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

  conv2 = Conv2D(64,3,activation='relu')(pool1)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

  conv3 = Conv2D(96,3,activation='relu')(pool2)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

  conv4 = Conv2D(128,3,activation='relu')(pool3)
  pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

  flat1 = Flatten()(pool4)

  # Votre dernière couche doit mettre à jour une variable prev_layer, réutilisée dans les couches de sortie ci-dessous
  prev_layer = Dense(512, activation='relu')(flat1)

  output_p = Dense(1, activation='sigmoid', name='p')(prev_layer)   # Sortie caractérisant la présence d'un objet
  output_coord = Dense(4, activation='linear', name='coord')(prev_layer) # Sortie caractérisant les coordonnées de boîte englobante
  output_class = Dense(num_classes, activation='softmax', name='classes')(prev_layer) # Sortie caractérisant les probabilités de classe

  output= [output_p, output_coord, output_class]
  model = Model(input_layer, output)

  return model

# %% [markdown]
# <center> <img src="https://drive.google.com/uc?id=1bnh8zU7Os-w-5TT8hV4xDoThKQc-Ywc2" width=500></center>
# <caption><center> Figure 4: Illustration des fonctions de coût à utiliser pour l'entraînement. </center></caption>
#
# Pour entraîner votre réseau, vous allez donc devoir associer une fonction de coût à chacune des sorties du réseau. La fonction de coût totale sera la somme des trois fonctions de coût précédemment définies, pondérées par des poids définis dans la variable *loss_weights*.
#
# **Prenez le temps de tester différentes valeurs de *loss_weights* en fonction de l'évolution des métriques que vous observerez pendant l'entraînement.**
#
# Vous évaluerez vos résultats de manière qualitative (en affichant les boîtes englobantes prédites et réelles) mais aussi quantitatives grâce aux fonctions définies dans la section précédente. **N'hésitez pas à modifier un peu le paramètre iou_threshold positionné par défaut à 0.5** (une valeur de 0.4 vous permettra d'obtenir de meilleurs résultats !)

# %%
batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)

# Ici mettre, dans l'ordre, les fonctions de coût associées à chacune des sorties
loss=['binary_crossentropy', 'mse', 'binary_crossentropy']
# On va associer une métrique à chaque sortie : l'accuracy pour les deux classifications,
# et l'IoU définie plus tôt pour la qualité des boîtes englobantes.
metrics=[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1, 1, 1]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )
history = model.fit(x_train, [y_train[:,0], y_train[:,1:5], y_train[:,5:]],
              epochs=50,
              batch_size=batch_size,
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 13s 21ms/step - loss: 1.3100 - p_loss: 0.0373 - coord_loss: 0.9239 - classes_loss: 0.3488 - p_accuracy: 0.9915 - coord_IoU: 0.3709 - classes_accuracy: 0.1220 - val_loss: 1.0893 - val_p_loss: 6.6149e-04 - val_coord_loss: 0.7865 - val_classes_loss: 0.3022 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4071 - val_classes_accuracy: 0.1381
# Epoch 2/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.9896 - p_loss: 0.0014 - coord_loss: 0.6961 - classes_loss: 0.2921 - p_accuracy: 1.0000 - coord_IoU: 0.4399 - classes_accuracy: 0.2757 - val_loss: 0.9649 - val_p_loss: 5.6921e-04 - val_coord_loss: 0.6897 - val_classes_loss: 0.2746 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4467 - val_classes_accuracy: 0.3143
# Epoch 3/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.8418 - p_loss: 7.3225e-04 - coord_loss: 0.5773 - classes_loss: 0.2638 - p_accuracy: 1.0000 - coord_IoU: 0.4807 - classes_accuracy: 0.3913 - val_loss: 0.7681 - val_p_loss: 4.3593e-04 - val_coord_loss: 0.5207 - val_classes_loss: 0.2470 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5199 - val_classes_accuracy: 0.3810
# Epoch 4/50
# 118/118 [==============================] - 1s 12ms/step - loss: 0.7491 - p_loss: 3.7532e-04 - coord_loss: 0.5113 - classes_loss: 0.2375 - p_accuracy: 1.0000 - coord_IoU: 0.5054 - classes_accuracy: 0.4449 - val_loss: 0.7040 - val_p_loss: 4.0276e-04 - val_coord_loss: 0.4747 - val_classes_loss: 0.2289 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5342 - val_classes_accuracy: 0.4048
# Epoch 5/50
# 118/118 [==============================] - 1s 12ms/step - loss: 0.6890 - p_loss: 2.5145e-04 - coord_loss: 0.4683 - classes_loss: 0.2205 - p_accuracy: 1.0000 - coord_IoU: 0.5222 - classes_accuracy: 0.4714 - val_loss: 0.6805 - val_p_loss: 3.5820e-04 - val_coord_loss: 0.4607 - val_classes_loss: 0.2194 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5320 - val_classes_accuracy: 0.4048
# Epoch 6/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.6427 - p_loss: 2.0678e-04 - coord_loss: 0.4325 - classes_loss: 0.2100 - p_accuracy: 1.0000 - coord_IoU: 0.5205 - classes_accuracy: 0.4841 - val_loss: 0.6449 - val_p_loss: 1.2075e-04 - val_coord_loss: 0.4361 - val_classes_loss: 0.2087 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5278 - val_classes_accuracy: 0.4143
# Epoch 7/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.5955 - p_loss: 1.2778e-04 - coord_loss: 0.3964 - classes_loss: 0.1990 - p_accuracy: 1.0000 - coord_IoU: 0.5497 - classes_accuracy: 0.4984 - val_loss: 0.6210 - val_p_loss: 8.2603e-05 - val_coord_loss: 0.4216 - val_classes_loss: 0.1993 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5456 - val_classes_accuracy: 0.4619
# Epoch 8/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.5638 - p_loss: 1.0289e-04 - coord_loss: 0.3721 - classes_loss: 0.1916 - p_accuracy: 1.0000 - coord_IoU: 0.5617 - classes_accuracy: 0.5297 - val_loss: 0.5794 - val_p_loss: 9.5684e-05 - val_coord_loss: 0.3856 - val_classes_loss: 0.1937 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5126 - val_classes_accuracy: 0.4714
# Epoch 9/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.5412 - p_loss: 8.6082e-05 - coord_loss: 0.3546 - classes_loss: 0.1865 - p_accuracy: 1.0000 - coord_IoU: 0.5556 - classes_accuracy: 0.5382 - val_loss: 0.5780 - val_p_loss: 6.4282e-05 - val_coord_loss: 0.3850 - val_classes_loss: 0.1930 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5556 - val_classes_accuracy: 0.5048
# Epoch 10/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.5081 - p_loss: 6.3051e-05 - coord_loss: 0.3276 - classes_loss: 0.1805 - p_accuracy: 1.0000 - coord_IoU: 0.5688 - classes_accuracy: 0.5514 - val_loss: 0.5540 - val_p_loss: 5.0431e-05 - val_coord_loss: 0.3690 - val_classes_loss: 0.1849 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5425 - val_classes_accuracy: 0.4952
# Epoch 11/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4774 - p_loss: 4.6223e-05 - coord_loss: 0.3031 - classes_loss: 0.1743 - p_accuracy: 1.0000 - coord_IoU: 0.5857 - classes_accuracy: 0.5748 - val_loss: 0.5241 - val_p_loss: 3.3099e-05 - val_coord_loss: 0.3449 - val_classes_loss: 0.1792 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5588 - val_classes_accuracy: 0.5190
# Epoch 12/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4523 - p_loss: 2.9466e-05 - coord_loss: 0.2830 - classes_loss: 0.1693 - p_accuracy: 1.0000 - coord_IoU: 0.5914 - classes_accuracy: 0.5891 - val_loss: 0.5458 - val_p_loss: 1.8467e-05 - val_coord_loss: 0.3687 - val_classes_loss: 0.1770 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5000 - val_classes_accuracy: 0.5286
# Epoch 13/50
# 118/118 [==============================] - 1s 13ms/step - loss: 0.4302 - p_loss: 2.5366e-05 - coord_loss: 0.2653 - classes_loss: 0.1649 - p_accuracy: 1.0000 - coord_IoU: 0.6017 - classes_accuracy: 0.6007 - val_loss: 0.5476 - val_p_loss: 2.1124e-05 - val_coord_loss: 0.3723 - val_classes_loss: 0.1753 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5190 - val_classes_accuracy: 0.5333
# Epoch 14/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.4167 - p_loss: 2.4359e-05 - coord_loss: 0.2556 - classes_loss: 0.1611 - p_accuracy: 1.0000 - coord_IoU: 0.6058 - classes_accuracy: 0.6034 - val_loss: 0.4917 - val_p_loss: 1.7565e-05 - val_coord_loss: 0.3233 - val_classes_loss: 0.1684 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5707 - val_classes_accuracy: 0.5476
# Epoch 15/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3963 - p_loss: 2.1309e-05 - coord_loss: 0.2392 - classes_loss: 0.1571 - p_accuracy: 1.0000 - coord_IoU: 0.6179 - classes_accuracy: 0.6113 - val_loss: 0.4890 - val_p_loss: 1.4685e-05 - val_coord_loss: 0.3226 - val_classes_loss: 0.1664 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5768 - val_classes_accuracy: 0.5667
# Epoch 16/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3774 - p_loss: 1.7484e-05 - coord_loss: 0.2242 - classes_loss: 0.1532 - p_accuracy: 1.0000 - coord_IoU: 0.6118 - classes_accuracy: 0.6188 - val_loss: 0.4972 - val_p_loss: 7.6528e-06 - val_coord_loss: 0.3351 - val_classes_loss: 0.1621 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5395 - val_classes_accuracy: 0.5714
# Epoch 17/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3576 - p_loss: 1.6500e-05 - coord_loss: 0.2086 - classes_loss: 0.1490 - p_accuracy: 1.0000 - coord_IoU: 0.6235 - classes_accuracy: 0.6341 - val_loss: 0.4707 - val_p_loss: 8.8921e-06 - val_coord_loss: 0.3122 - val_classes_loss: 0.1585 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5888 - val_classes_accuracy: 0.6048
# Epoch 18/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3415 - p_loss: 1.2572e-05 - coord_loss: 0.1949 - classes_loss: 0.1466 - p_accuracy: 1.0000 - coord_IoU: 0.6373 - classes_accuracy: 0.6288 - val_loss: 0.4647 - val_p_loss: 8.8367e-06 - val_coord_loss: 0.3075 - val_classes_loss: 0.1571 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5954 - val_classes_accuracy: 0.5667
# Epoch 19/50
# 118/118 [==============================] - 1s 10ms/step - loss: 0.3297 - p_loss: 1.0764e-05 - coord_loss: 0.1856 - classes_loss: 0.1441 - p_accuracy: 1.0000 - coord_IoU: 0.6345 - classes_accuracy: 0.6458 - val_loss: 0.4764 - val_p_loss: 3.9009e-06 - val_coord_loss: 0.3204 - val_classes_loss: 0.1560 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5542 - val_classes_accuracy: 0.5952
# Epoch 20/50
# 118/118 [==============================] - 1s 12ms/step - loss: 0.3151 - p_loss: 8.8650e-06 - coord_loss: 0.1741 - classes_loss: 0.1410 - p_accuracy: 1.0000 - coord_IoU: 0.6455 - classes_accuracy: 0.6442 - val_loss: 0.4460 - val_p_loss: 5.2124e-06 - val_coord_loss: 0.2917 - val_classes_loss: 0.1543 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5867 - val_classes_accuracy: 0.5857
# Epoch 21/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.3072 - p_loss: 9.5673e-06 - coord_loss: 0.1691 - classes_loss: 0.1381 - p_accuracy: 1.0000 - coord_IoU: 0.6547 - classes_accuracy: 0.6554 - val_loss: 0.4755 - val_p_loss: 4.4269e-06 - val_coord_loss: 0.3257 - val_classes_loss: 0.1497 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5892 - val_classes_accuracy: 0.6000
# Epoch 22/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.2963 - p_loss: 9.5107e-06 - coord_loss: 0.1600 - classes_loss: 0.1362 - p_accuracy: 1.0000 - coord_IoU: 0.6603 - classes_accuracy: 0.6644 - val_loss: 0.4505 - val_p_loss: 5.2241e-06 - val_coord_loss: 0.3027 - val_classes_loss: 0.1478 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5995 - val_classes_accuracy: 0.6000
# Epoch 23/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2782 - p_loss: 6.2232e-06 - coord_loss: 0.1450 - classes_loss: 0.1332 - p_accuracy: 1.0000 - coord_IoU: 0.6683 - classes_accuracy: 0.6676 - val_loss: 0.4381 - val_p_loss: 5.8680e-06 - val_coord_loss: 0.2900 - val_classes_loss: 0.1481 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5853 - val_classes_accuracy: 0.6238
# Epoch 24/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2673 - p_loss: 5.3802e-06 - coord_loss: 0.1366 - classes_loss: 0.1306 - p_accuracy: 1.0000 - coord_IoU: 0.6713 - classes_accuracy: 0.6835 - val_loss: 0.4471 - val_p_loss: 3.0910e-06 - val_coord_loss: 0.3032 - val_classes_loss: 0.1439 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5895 - val_classes_accuracy: 0.6095
# Epoch 25/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2581 - p_loss: 4.6444e-06 - coord_loss: 0.1306 - classes_loss: 0.1275 - p_accuracy: 1.0000 - coord_IoU: 0.6763 - classes_accuracy: 0.6850 - val_loss: 0.4645 - val_p_loss: 5.6947e-06 - val_coord_loss: 0.3185 - val_classes_loss: 0.1460 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5732 - val_classes_accuracy: 0.6048
# Epoch 26/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2601 - p_loss: 5.4506e-06 - coord_loss: 0.1345 - classes_loss: 0.1256 - p_accuracy: 1.0000 - coord_IoU: 0.6734 - classes_accuracy: 0.6957 - val_loss: 0.4563 - val_p_loss: 3.1988e-06 - val_coord_loss: 0.3149 - val_classes_loss: 0.1414 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5494 - val_classes_accuracy: 0.6381
# Epoch 27/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2382 - p_loss: 4.8337e-06 - coord_loss: 0.1155 - classes_loss: 0.1227 - p_accuracy: 1.0000 - coord_IoU: 0.6792 - classes_accuracy: 0.7089 - val_loss: 0.4510 - val_p_loss: 3.4753e-06 - val_coord_loss: 0.3104 - val_classes_loss: 0.1406 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5880 - val_classes_accuracy: 0.6333
# Epoch 28/50
# 118/118 [==============================] - 1s 12ms/step - loss: 0.2291 - p_loss: 3.5914e-06 - coord_loss: 0.1089 - classes_loss: 0.1201 - p_accuracy: 1.0000 - coord_IoU: 0.6989 - classes_accuracy: 0.7084 - val_loss: 0.4191 - val_p_loss: 2.7737e-06 - val_coord_loss: 0.2775 - val_classes_loss: 0.1416 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5949 - val_classes_accuracy: 0.6381
# Epoch 29/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.2209 - p_loss: 2.7471e-06 - coord_loss: 0.1031 - classes_loss: 0.1178 - p_accuracy: 1.0000 - coord_IoU: 0.7000 - classes_accuracy: 0.7285 - val_loss: 0.4222 - val_p_loss: 2.0442e-06 - val_coord_loss: 0.2829 - val_classes_loss: 0.1393 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5981 - val_classes_accuracy: 0.6333
# Epoch 30/50
# 118/118 [==============================] - 1s 12ms/step - loss: 0.2224 - p_loss: 3.0890e-06 - coord_loss: 0.1064 - classes_loss: 0.1159 - p_accuracy: 1.0000 - coord_IoU: 0.6922 - classes_accuracy: 0.7349 - val_loss: 0.4271 - val_p_loss: 2.4888e-06 - val_coord_loss: 0.2901 - val_classes_loss: 0.1370 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6045 - val_classes_accuracy: 0.6381
# Epoch 31/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2078 - p_loss: 3.0871e-06 - coord_loss: 0.0942 - classes_loss: 0.1136 - p_accuracy: 1.0000 - coord_IoU: 0.7108 - classes_accuracy: 0.7333 - val_loss: 0.4531 - val_p_loss: 2.6845e-06 - val_coord_loss: 0.3141 - val_classes_loss: 0.1390 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5921 - val_classes_accuracy: 0.6333
# Epoch 32/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2046 - p_loss: 2.4062e-06 - coord_loss: 0.0930 - classes_loss: 0.1115 - p_accuracy: 1.0000 - coord_IoU: 0.7133 - classes_accuracy: 0.7428 - val_loss: 0.4296 - val_p_loss: 1.4329e-06 - val_coord_loss: 0.2941 - val_classes_loss: 0.1355 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5759 - val_classes_accuracy: 0.6429
# Epoch 33/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1958 - p_loss: 2.2877e-06 - coord_loss: 0.0863 - classes_loss: 0.1095 - p_accuracy: 1.0000 - coord_IoU: 0.7123 - classes_accuracy: 0.7455 - val_loss: 0.4475 - val_p_loss: 1.0078e-06 - val_coord_loss: 0.3122 - val_classes_loss: 0.1354 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5589 - val_classes_accuracy: 0.6524
# Epoch 34/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1892 - p_loss: 1.8461e-06 - coord_loss: 0.0823 - classes_loss: 0.1069 - p_accuracy: 1.0000 - coord_IoU: 0.7144 - classes_accuracy: 0.7550 - val_loss: 0.4363 - val_p_loss: 1.2289e-06 - val_coord_loss: 0.3018 - val_classes_loss: 0.1345 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5965 - val_classes_accuracy: 0.6667
# Epoch 35/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1872 - p_loss: 1.5982e-06 - coord_loss: 0.0821 - classes_loss: 0.1051 - p_accuracy: 1.0000 - coord_IoU: 0.7240 - classes_accuracy: 0.7667 - val_loss: 0.4141 - val_p_loss: 1.2456e-06 - val_coord_loss: 0.2834 - val_classes_loss: 0.1307 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5842 - val_classes_accuracy: 0.6810
# Epoch 36/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1763 - p_loss: 1.5015e-06 - coord_loss: 0.0733 - classes_loss: 0.1030 - p_accuracy: 1.0000 - coord_IoU: 0.7294 - classes_accuracy: 0.7635 - val_loss: 0.4110 - val_p_loss: 1.1244e-06 - val_coord_loss: 0.2792 - val_classes_loss: 0.1318 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5715 - val_classes_accuracy: 0.6952
# Epoch 37/50
# 118/118 [==============================] - 1s 12ms/step - loss: 0.1738 - p_loss: 1.4877e-06 - coord_loss: 0.0740 - classes_loss: 0.0998 - p_accuracy: 1.0000 - coord_IoU: 0.7253 - classes_accuracy: 0.7821 - val_loss: 0.4320 - val_p_loss: 1.0547e-06 - val_coord_loss: 0.3029 - val_classes_loss: 0.1291 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5659 - val_classes_accuracy: 0.6857
# Epoch 38/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1682 - p_loss: 1.2905e-06 - coord_loss: 0.0696 - classes_loss: 0.0986 - p_accuracy: 1.0000 - coord_IoU: 0.7379 - classes_accuracy: 0.7757 - val_loss: 0.4480 - val_p_loss: 1.0654e-06 - val_coord_loss: 0.3177 - val_classes_loss: 0.1303 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5544 - val_classes_accuracy: 0.6857
# Epoch 39/50
# 118/118 [==============================] - 1s 13ms/step - loss: 0.1643 - p_loss: 1.0911e-06 - coord_loss: 0.0682 - classes_loss: 0.0960 - p_accuracy: 1.0000 - coord_IoU: 0.7282 - classes_accuracy: 0.7842 - val_loss: 0.4303 - val_p_loss: 1.1332e-06 - val_coord_loss: 0.2972 - val_classes_loss: 0.1330 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5712 - val_classes_accuracy: 0.6762
# Epoch 40/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1552 - p_loss: 1.0181e-06 - coord_loss: 0.0620 - classes_loss: 0.0932 - p_accuracy: 1.0000 - coord_IoU: 0.7382 - classes_accuracy: 0.7980 - val_loss: 0.4174 - val_p_loss: 8.8457e-07 - val_coord_loss: 0.2885 - val_classes_loss: 0.1289 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5938 - val_classes_accuracy: 0.7048
# Epoch 41/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1542 - p_loss: 8.5635e-07 - coord_loss: 0.0628 - classes_loss: 0.0914 - p_accuracy: 1.0000 - coord_IoU: 0.7491 - classes_accuracy: 0.8075 - val_loss: 0.4221 - val_p_loss: 1.0098e-06 - val_coord_loss: 0.2903 - val_classes_loss: 0.1318 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5784 - val_classes_accuracy: 0.6905
# Epoch 42/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1463 - p_loss: 7.4006e-07 - coord_loss: 0.0565 - classes_loss: 0.0898 - p_accuracy: 1.0000 - coord_IoU: 0.7635 - classes_accuracy: 0.8059 - val_loss: 0.4172 - val_p_loss: 4.3036e-07 - val_coord_loss: 0.2903 - val_classes_loss: 0.1269 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5757 - val_classes_accuracy: 0.7143
# Epoch 43/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1442 - p_loss: 5.9114e-07 - coord_loss: 0.0566 - classes_loss: 0.0876 - p_accuracy: 1.0000 - coord_IoU: 0.7561 - classes_accuracy: 0.8128 - val_loss: 0.4224 - val_p_loss: 3.2291e-07 - val_coord_loss: 0.2933 - val_classes_loss: 0.1290 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5972 - val_classes_accuracy: 0.7048
# Epoch 44/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1444 - p_loss: 5.9682e-07 - coord_loss: 0.0584 - classes_loss: 0.0860 - p_accuracy: 1.0000 - coord_IoU: 0.7459 - classes_accuracy: 0.8203 - val_loss: 0.4155 - val_p_loss: 5.9989e-07 - val_coord_loss: 0.2881 - val_classes_loss: 0.1275 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6004 - val_classes_accuracy: 0.6952
# Epoch 45/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1344 - p_loss: 5.6953e-07 - coord_loss: 0.0512 - classes_loss: 0.0832 - p_accuracy: 1.0000 - coord_IoU: 0.7639 - classes_accuracy: 0.8277 - val_loss: 0.4098 - val_p_loss: 4.5836e-07 - val_coord_loss: 0.2840 - val_classes_loss: 0.1258 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5915 - val_classes_accuracy: 0.6952
# Epoch 46/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1317 - p_loss: 4.8509e-07 - coord_loss: 0.0507 - classes_loss: 0.0810 - p_accuracy: 1.0000 - coord_IoU: 0.7672 - classes_accuracy: 0.8340 - val_loss: 0.4097 - val_p_loss: 4.4165e-07 - val_coord_loss: 0.2801 - val_classes_loss: 0.1295 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5903 - val_classes_accuracy: 0.6857
# Epoch 47/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1280 - p_loss: 3.9605e-07 - coord_loss: 0.0487 - classes_loss: 0.0793 - p_accuracy: 1.0000 - coord_IoU: 0.7681 - classes_accuracy: 0.8362 - val_loss: 0.4183 - val_p_loss: 3.8065e-07 - val_coord_loss: 0.2933 - val_classes_loss: 0.1250 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5959 - val_classes_accuracy: 0.6952
# Epoch 48/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.1263 - p_loss: 4.2166e-07 - coord_loss: 0.0487 - classes_loss: 0.0776 - p_accuracy: 1.0000 - coord_IoU: 0.7762 - classes_accuracy: 0.8441 - val_loss: 0.4198 - val_p_loss: 4.0690e-07 - val_coord_loss: 0.2934 - val_classes_loss: 0.1264 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5857 - val_classes_accuracy: 0.6905
# Epoch 49/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1205 - p_loss: 3.4090e-07 - coord_loss: 0.0457 - classes_loss: 0.0748 - p_accuracy: 1.0000 - coord_IoU: 0.7775 - classes_accuracy: 0.8521 - val_loss: 0.4139 - val_p_loss: 2.9174e-07 - val_coord_loss: 0.2886 - val_classes_loss: 0.1253 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5918 - val_classes_accuracy: 0.7190
# Epoch 50/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1172 - p_loss: 3.0144e-07 - coord_loss: 0.0435 - classes_loss: 0.0737 - p_accuracy: 1.0000 - coord_IoU: 0.7795 - classes_accuracy: 0.8600 - val_loss: 0.4259 - val_p_loss: 4.2181e-07 - val_coord_loss: 0.3015 - val_classes_loss: 0.1244 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5783 - val_classes_accuracy: 0.7095

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_IoU')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)
# Out:
# 8/8 [==============================] - 1s 26ms/step
# <ipython-input-15-9343505547b4>:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_pred[i, 0] = y_pred_presence[i]

# %%
class_res, accuracy = global_accuracy(y_test, y_pred)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("------------------------------------------")
# Out:
# La précision globale est de 45.5%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.44    |  0.36  |   0.40   |
# ------------------------------------------
# | VEREUR |   0.42    |  0.50  |   0.46   |
# ------------------------------------------
# | ECUROU |   0.86    |  0.86  |   0.86   |
# ------------------------------------------
# | PIEBAV |   0.86    |  0.86  |   0.86   |
# ------------------------------------------
# | SITTOR |   0.36    |  0.36  |   0.36   |
# ------------------------------------------
# | PINARB |   0.44    |  0.50  |   0.47   |
# ------------------------------------------
# | MESNOI |   0.19    |  0.21  |   0.20   |
# ------------------------------------------
# | MESNON |   0.22    |  0.18  |   0.20   |
# ------------------------------------------
# | MESBLE |   0.21    |  0.18  |   0.20   |
# ------------------------------------------
# | ROUGOR |   0.52    |  0.52  |   0.52   |
# ------------------------------------------
# | ACCMOU |   0.33    |  0.36  |   0.35   |
# ------------------------------------------

# %% [markdown]
# En pratique, il est délicat de trouver une bonne combinaison des fonctions de perte tel que vous l'avez fait sur les cellules précédentes. L'entropie croisée et l'erreur quadratique moyenne donnent des valeurs trop différentes pour être combinables efficacement.
#
# Une variante, peut-être plus simple à faire fonctionner, est d'utiliser uniquement l'erreur quadratique moyenne comme perte pour toutes les sorties. C'est cette variante qui est implémentée dans l'algorithme YOLO, dont nous implémenterons une version simplifiée dans le prochain TP.
# Testez cette solution ci-dessous. Comme sur l'exercice précédent, n'hésitez pas à faire varier le poids des différents éléments de la fonction de coût.

# %%
batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)

loss = ['binary_crossentropy', 'mse', 'binary_crossentropy']
metrics =[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1,1,1]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )
history = model.fit(x_train, [y_train[:,0], y_train[:,1:5], y_train[:,5:]],
              epochs=50,
              batch_size=batch_size,
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 6s 14ms/step - loss: 1.2632 - p_loss: 0.0306 - coord_loss: 0.8832 - classes_loss: 0.3494 - p_accuracy: 1.0000 - coord_IoU: 0.3816 - classes_accuracy: 0.1622 - val_loss: 1.0411 - val_p_loss: 5.8073e-04 - val_coord_loss: 0.7453 - val_classes_loss: 0.2952 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4119 - val_classes_accuracy: 0.3048
# Epoch 2/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.9495 - p_loss: 0.0012 - coord_loss: 0.6624 - classes_loss: 0.2858 - p_accuracy: 1.0000 - coord_IoU: 0.4487 - classes_accuracy: 0.3324 - val_loss: 0.8755 - val_p_loss: 4.2550e-04 - val_coord_loss: 0.6090 - val_classes_loss: 0.2661 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4877 - val_classes_accuracy: 0.3286
# Epoch 3/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.8235 - p_loss: 6.2088e-04 - coord_loss: 0.5643 - classes_loss: 0.2585 - p_accuracy: 1.0000 - coord_IoU: 0.4818 - classes_accuracy: 0.3913 - val_loss: 0.7599 - val_p_loss: 3.0611e-04 - val_coord_loss: 0.5160 - val_classes_loss: 0.2436 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5117 - val_classes_accuracy: 0.3857
# Epoch 4/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.7363 - p_loss: 3.3876e-04 - coord_loss: 0.4994 - classes_loss: 0.2366 - p_accuracy: 1.0000 - coord_IoU: 0.5106 - classes_accuracy: 0.4406 - val_loss: 0.7459 - val_p_loss: 1.4567e-04 - val_coord_loss: 0.5207 - val_classes_loss: 0.2250 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5183 - val_classes_accuracy: 0.3762
# Epoch 5/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.6848 - p_loss: 1.9963e-04 - coord_loss: 0.4633 - classes_loss: 0.2213 - p_accuracy: 1.0000 - coord_IoU: 0.5271 - classes_accuracy: 0.4820 - val_loss: 0.6804 - val_p_loss: 2.3180e-04 - val_coord_loss: 0.4648 - val_classes_loss: 0.2153 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5082 - val_classes_accuracy: 0.4714
# Epoch 6/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.6385 - p_loss: 2.0091e-04 - coord_loss: 0.4281 - classes_loss: 0.2102 - p_accuracy: 1.0000 - coord_IoU: 0.5319 - classes_accuracy: 0.5133 - val_loss: 0.6163 - val_p_loss: 1.2988e-04 - val_coord_loss: 0.4094 - val_classes_loss: 0.2068 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5454 - val_classes_accuracy: 0.4667
# Epoch 7/50
# 118/118 [==============================] - 1s 12ms/step - loss: 0.5938 - p_loss: 1.4605e-04 - coord_loss: 0.3931 - classes_loss: 0.2006 - p_accuracy: 1.0000 - coord_IoU: 0.5525 - classes_accuracy: 0.5260 - val_loss: 0.6274 - val_p_loss: 7.4137e-05 - val_coord_loss: 0.4274 - val_classes_loss: 0.1999 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5045 - val_classes_accuracy: 0.4619
# Epoch 8/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.5537 - p_loss: 1.0407e-04 - coord_loss: 0.3612 - classes_loss: 0.1924 - p_accuracy: 1.0000 - coord_IoU: 0.5559 - classes_accuracy: 0.5419 - val_loss: 0.5580 - val_p_loss: 7.9255e-05 - val_coord_loss: 0.3651 - val_classes_loss: 0.1928 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5765 - val_classes_accuracy: 0.5000
# Epoch 9/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.5262 - p_loss: 7.5778e-05 - coord_loss: 0.3409 - classes_loss: 0.1851 - p_accuracy: 1.0000 - coord_IoU: 0.5658 - classes_accuracy: 0.5541 - val_loss: 0.5596 - val_p_loss: 6.0794e-05 - val_coord_loss: 0.3733 - val_classes_loss: 0.1863 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5342 - val_classes_accuracy: 0.4857
# Epoch 10/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.4833 - p_loss: 5.4548e-05 - coord_loss: 0.3046 - classes_loss: 0.1787 - p_accuracy: 1.0000 - coord_IoU: 0.5854 - classes_accuracy: 0.5631 - val_loss: 0.5166 - val_p_loss: 2.5432e-05 - val_coord_loss: 0.3369 - val_classes_loss: 0.1797 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5875 - val_classes_accuracy: 0.5048
# Epoch 11/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.4686 - p_loss: 3.9205e-05 - coord_loss: 0.2943 - classes_loss: 0.1743 - p_accuracy: 1.0000 - coord_IoU: 0.5898 - classes_accuracy: 0.5785 - val_loss: 0.5402 - val_p_loss: 2.3465e-05 - val_coord_loss: 0.3637 - val_classes_loss: 0.1765 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5313 - val_classes_accuracy: 0.4952
# Epoch 12/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.4417 - p_loss: 2.7236e-05 - coord_loss: 0.2715 - classes_loss: 0.1702 - p_accuracy: 1.0000 - coord_IoU: 0.6030 - classes_accuracy: 0.5843 - val_loss: 0.5028 - val_p_loss: 6.7279e-06 - val_coord_loss: 0.3301 - val_classes_loss: 0.1726 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5693 - val_classes_accuracy: 0.5333
# Epoch 13/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.4277 - p_loss: 3.2632e-05 - coord_loss: 0.2616 - classes_loss: 0.1661 - p_accuracy: 1.0000 - coord_IoU: 0.6044 - classes_accuracy: 0.6066 - val_loss: 0.5174 - val_p_loss: 1.3789e-05 - val_coord_loss: 0.3488 - val_classes_loss: 0.1686 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5746 - val_classes_accuracy: 0.5571
# Epoch 14/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3944 - p_loss: 2.0440e-05 - coord_loss: 0.2328 - classes_loss: 0.1616 - p_accuracy: 1.0000 - coord_IoU: 0.6185 - classes_accuracy: 0.6172 - val_loss: 0.4842 - val_p_loss: 1.0164e-05 - val_coord_loss: 0.3180 - val_classes_loss: 0.1662 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5920 - val_classes_accuracy: 0.5286
# Epoch 15/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3754 - p_loss: 1.4603e-05 - coord_loss: 0.2175 - classes_loss: 0.1578 - p_accuracy: 1.0000 - coord_IoU: 0.6301 - classes_accuracy: 0.6214 - val_loss: 0.4866 - val_p_loss: 9.8518e-06 - val_coord_loss: 0.3227 - val_classes_loss: 0.1639 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5171 - val_classes_accuracy: 0.5810
# Epoch 16/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3598 - p_loss: 1.2206e-05 - coord_loss: 0.2058 - classes_loss: 0.1540 - p_accuracy: 1.0000 - coord_IoU: 0.6274 - classes_accuracy: 0.6331 - val_loss: 0.4630 - val_p_loss: 1.3836e-05 - val_coord_loss: 0.3006 - val_classes_loss: 0.1624 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5992 - val_classes_accuracy: 0.5667
# Epoch 17/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.3427 - p_loss: 1.3141e-05 - coord_loss: 0.1912 - classes_loss: 0.1515 - p_accuracy: 1.0000 - coord_IoU: 0.6402 - classes_accuracy: 0.6357 - val_loss: 0.4673 - val_p_loss: 7.1676e-06 - val_coord_loss: 0.3088 - val_classes_loss: 0.1585 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5919 - val_classes_accuracy: 0.5905
# Epoch 18/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.3245 - p_loss: 6.8222e-06 - coord_loss: 0.1767 - classes_loss: 0.1478 - p_accuracy: 1.0000 - coord_IoU: 0.6496 - classes_accuracy: 0.6389 - val_loss: 0.4690 - val_p_loss: 2.7881e-06 - val_coord_loss: 0.3128 - val_classes_loss: 0.1563 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6057 - val_classes_accuracy: 0.5762
# Epoch 19/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.3151 - p_loss: 7.0309e-06 - coord_loss: 0.1690 - classes_loss: 0.1461 - p_accuracy: 1.0000 - coord_IoU: 0.6474 - classes_accuracy: 0.6453 - val_loss: 0.4536 - val_p_loss: 5.0120e-06 - val_coord_loss: 0.2990 - val_classes_loss: 0.1546 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6005 - val_classes_accuracy: 0.6000
# Epoch 20/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2933 - p_loss: 5.5981e-06 - coord_loss: 0.1505 - classes_loss: 0.1428 - p_accuracy: 1.0000 - coord_IoU: 0.6684 - classes_accuracy: 0.6596 - val_loss: 0.4732 - val_p_loss: 2.3092e-06 - val_coord_loss: 0.3225 - val_classes_loss: 0.1508 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5924 - val_classes_accuracy: 0.6095
# Epoch 21/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2851 - p_loss: 4.1803e-06 - coord_loss: 0.1457 - classes_loss: 0.1393 - p_accuracy: 1.0000 - coord_IoU: 0.6644 - classes_accuracy: 0.6569 - val_loss: 0.4596 - val_p_loss: 4.0124e-06 - val_coord_loss: 0.3082 - val_classes_loss: 0.1515 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5732 - val_classes_accuracy: 0.5810
# Epoch 22/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2796 - p_loss: 4.3258e-06 - coord_loss: 0.1428 - classes_loss: 0.1369 - p_accuracy: 1.0000 - coord_IoU: 0.6654 - classes_accuracy: 0.6660 - val_loss: 0.4581 - val_p_loss: 1.4725e-06 - val_coord_loss: 0.3108 - val_classes_loss: 0.1473 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5381 - val_classes_accuracy: 0.6476
# Epoch 23/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2644 - p_loss: 2.9277e-06 - coord_loss: 0.1294 - classes_loss: 0.1350 - p_accuracy: 1.0000 - coord_IoU: 0.6729 - classes_accuracy: 0.6766 - val_loss: 0.4264 - val_p_loss: 1.2587e-06 - val_coord_loss: 0.2800 - val_classes_loss: 0.1464 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5879 - val_classes_accuracy: 0.6286
# Epoch 24/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2595 - p_loss: 3.4746e-06 - coord_loss: 0.1262 - classes_loss: 0.1333 - p_accuracy: 1.0000 - coord_IoU: 0.6967 - classes_accuracy: 0.6829 - val_loss: 0.4449 - val_p_loss: 2.3350e-06 - val_coord_loss: 0.2990 - val_classes_loss: 0.1459 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6146 - val_classes_accuracy: 0.6476
# Epoch 25/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2492 - p_loss: 2.6557e-06 - coord_loss: 0.1190 - classes_loss: 0.1303 - p_accuracy: 1.0000 - coord_IoU: 0.6867 - classes_accuracy: 0.6919 - val_loss: 0.4275 - val_p_loss: 1.7289e-06 - val_coord_loss: 0.2849 - val_classes_loss: 0.1426 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6048 - val_classes_accuracy: 0.6381
# Epoch 26/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2419 - p_loss: 2.7177e-06 - coord_loss: 0.1140 - classes_loss: 0.1279 - p_accuracy: 1.0000 - coord_IoU: 0.6987 - classes_accuracy: 0.6951 - val_loss: 0.4331 - val_p_loss: 1.2482e-06 - val_coord_loss: 0.2909 - val_classes_loss: 0.1422 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5658 - val_classes_accuracy: 0.6429
# Epoch 27/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.2229 - p_loss: 1.8593e-06 - coord_loss: 0.0977 - classes_loss: 0.1252 - p_accuracy: 1.0000 - coord_IoU: 0.7122 - classes_accuracy: 0.7100 - val_loss: 0.4267 - val_p_loss: 9.8464e-07 - val_coord_loss: 0.2857 - val_classes_loss: 0.1410 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5875 - val_classes_accuracy: 0.6238
# Epoch 28/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2129 - p_loss: 1.4355e-06 - coord_loss: 0.0908 - classes_loss: 0.1221 - p_accuracy: 1.0000 - coord_IoU: 0.7189 - classes_accuracy: 0.7073 - val_loss: 0.4228 - val_p_loss: 7.3885e-07 - val_coord_loss: 0.2828 - val_classes_loss: 0.1399 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5924 - val_classes_accuracy: 0.6286
# Epoch 29/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2083 - p_loss: 1.4759e-06 - coord_loss: 0.0891 - classes_loss: 0.1192 - p_accuracy: 1.0000 - coord_IoU: 0.7165 - classes_accuracy: 0.7232 - val_loss: 0.4227 - val_p_loss: 1.0698e-06 - val_coord_loss: 0.2838 - val_classes_loss: 0.1389 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6076 - val_classes_accuracy: 0.6476
# Epoch 30/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.2075 - p_loss: 1.8148e-06 - coord_loss: 0.0889 - classes_loss: 0.1186 - p_accuracy: 1.0000 - coord_IoU: 0.7172 - classes_accuracy: 0.7200 - val_loss: 0.4399 - val_p_loss: 9.5811e-07 - val_coord_loss: 0.2994 - val_classes_loss: 0.1405 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5831 - val_classes_accuracy: 0.6381
# Epoch 31/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1974 - p_loss: 1.4368e-06 - coord_loss: 0.0808 - classes_loss: 0.1165 - p_accuracy: 1.0000 - coord_IoU: 0.7202 - classes_accuracy: 0.7301 - val_loss: 0.4051 - val_p_loss: 6.2468e-07 - val_coord_loss: 0.2708 - val_classes_loss: 0.1343 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6091 - val_classes_accuracy: 0.6619
# Epoch 32/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1864 - p_loss: 1.0330e-06 - coord_loss: 0.0736 - classes_loss: 0.1127 - p_accuracy: 1.0000 - coord_IoU: 0.7356 - classes_accuracy: 0.7460 - val_loss: 0.4395 - val_p_loss: 5.6096e-07 - val_coord_loss: 0.3027 - val_classes_loss: 0.1368 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5549 - val_classes_accuracy: 0.6619
# Epoch 33/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1845 - p_loss: 1.0761e-06 - coord_loss: 0.0731 - classes_loss: 0.1114 - p_accuracy: 1.0000 - coord_IoU: 0.7332 - classes_accuracy: 0.7423 - val_loss: 0.4308 - val_p_loss: 8.0637e-07 - val_coord_loss: 0.2986 - val_classes_loss: 0.1322 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6045 - val_classes_accuracy: 0.6762
# Epoch 34/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1729 - p_loss: 9.1503e-07 - coord_loss: 0.0647 - classes_loss: 0.1083 - p_accuracy: 1.0000 - coord_IoU: 0.7541 - classes_accuracy: 0.7566 - val_loss: 0.4092 - val_p_loss: 6.8667e-07 - val_coord_loss: 0.2781 - val_classes_loss: 0.1311 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5901 - val_classes_accuracy: 0.6667
# Epoch 35/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.1708 - p_loss: 7.1760e-07 - coord_loss: 0.0639 - classes_loss: 0.1068 - p_accuracy: 1.0000 - coord_IoU: 0.7393 - classes_accuracy: 0.7572 - val_loss: 0.4227 - val_p_loss: 5.2535e-07 - val_coord_loss: 0.2888 - val_classes_loss: 0.1339 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6232 - val_classes_accuracy: 0.6905
# Epoch 36/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1695 - p_loss: 9.0204e-07 - coord_loss: 0.0650 - classes_loss: 0.1045 - p_accuracy: 1.0000 - coord_IoU: 0.7411 - classes_accuracy: 0.7662 - val_loss: 0.4146 - val_p_loss: 3.4027e-07 - val_coord_loss: 0.2844 - val_classes_loss: 0.1302 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6101 - val_classes_accuracy: 0.6857
# Epoch 37/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1644 - p_loss: 8.7683e-07 - coord_loss: 0.0618 - classes_loss: 0.1026 - p_accuracy: 1.0000 - coord_IoU: 0.7481 - classes_accuracy: 0.7709 - val_loss: 0.4477 - val_p_loss: 6.0714e-07 - val_coord_loss: 0.3108 - val_classes_loss: 0.1369 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5858 - val_classes_accuracy: 0.6429
# Epoch 38/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1624 - p_loss: 8.8303e-07 - coord_loss: 0.0625 - classes_loss: 0.0999 - p_accuracy: 1.0000 - coord_IoU: 0.7514 - classes_accuracy: 0.7773 - val_loss: 0.4226 - val_p_loss: 4.9344e-07 - val_coord_loss: 0.2940 - val_classes_loss: 0.1286 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5953 - val_classes_accuracy: 0.6952
# Epoch 39/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1520 - p_loss: 6.9858e-07 - coord_loss: 0.0543 - classes_loss: 0.0976 - p_accuracy: 1.0000 - coord_IoU: 0.7547 - classes_accuracy: 0.7831 - val_loss: 0.3942 - val_p_loss: 2.9217e-07 - val_coord_loss: 0.2663 - val_classes_loss: 0.1278 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6270 - val_classes_accuracy: 0.6905
# Epoch 40/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1472 - p_loss: 5.5092e-07 - coord_loss: 0.0528 - classes_loss: 0.0944 - p_accuracy: 1.0000 - coord_IoU: 0.7644 - classes_accuracy: 0.7900 - val_loss: 0.4205 - val_p_loss: 1.7238e-07 - val_coord_loss: 0.2927 - val_classes_loss: 0.1277 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5972 - val_classes_accuracy: 0.6857
# Epoch 41/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1465 - p_loss: 6.0886e-07 - coord_loss: 0.0537 - classes_loss: 0.0928 - p_accuracy: 1.0000 - coord_IoU: 0.7621 - classes_accuracy: 0.7990 - val_loss: 0.4293 - val_p_loss: 3.8037e-07 - val_coord_loss: 0.3000 - val_classes_loss: 0.1293 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5996 - val_classes_accuracy: 0.6667
# Epoch 42/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1456 - p_loss: 6.8632e-07 - coord_loss: 0.0540 - classes_loss: 0.0915 - p_accuracy: 1.0000 - coord_IoU: 0.7605 - classes_accuracy: 0.8001 - val_loss: 0.4284 - val_p_loss: 4.0485e-07 - val_coord_loss: 0.2990 - val_classes_loss: 0.1294 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6148 - val_classes_accuracy: 0.6857
# Epoch 43/50
# 118/118 [==============================] - 1s 12ms/step - loss: 0.1382 - p_loss: 5.2048e-07 - coord_loss: 0.0500 - classes_loss: 0.0881 - p_accuracy: 1.0000 - coord_IoU: 0.7586 - classes_accuracy: 0.8033 - val_loss: 0.4007 - val_p_loss: 2.4180e-07 - val_coord_loss: 0.2777 - val_classes_loss: 0.1230 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6123 - val_classes_accuracy: 0.7048
# Epoch 44/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1330 - p_loss: 4.5393e-07 - coord_loss: 0.0467 - classes_loss: 0.0863 - p_accuracy: 1.0000 - coord_IoU: 0.7761 - classes_accuracy: 0.8139 - val_loss: 0.4038 - val_p_loss: 1.9919e-07 - val_coord_loss: 0.2796 - val_classes_loss: 0.1242 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6250 - val_classes_accuracy: 0.7381
# Epoch 45/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1264 - p_loss: 3.3459e-07 - coord_loss: 0.0423 - classes_loss: 0.0842 - p_accuracy: 1.0000 - coord_IoU: 0.7739 - classes_accuracy: 0.8245 - val_loss: 0.4221 - val_p_loss: 1.5041e-07 - val_coord_loss: 0.2967 - val_classes_loss: 0.1255 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6241 - val_classes_accuracy: 0.7095
# Epoch 46/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1264 - p_loss: 3.0639e-07 - coord_loss: 0.0450 - classes_loss: 0.0814 - p_accuracy: 1.0000 - coord_IoU: 0.7844 - classes_accuracy: 0.8287 - val_loss: 0.4059 - val_p_loss: 2.0367e-07 - val_coord_loss: 0.2792 - val_classes_loss: 0.1267 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6352 - val_classes_accuracy: 0.7238
# Epoch 47/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1259 - p_loss: 3.8403e-07 - coord_loss: 0.0465 - classes_loss: 0.0794 - p_accuracy: 1.0000 - coord_IoU: 0.7754 - classes_accuracy: 0.8287 - val_loss: 0.4005 - val_p_loss: 3.0810e-07 - val_coord_loss: 0.2764 - val_classes_loss: 0.1241 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6225 - val_classes_accuracy: 0.7143
# Epoch 48/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1217 - p_loss: 3.1427e-07 - coord_loss: 0.0437 - classes_loss: 0.0780 - p_accuracy: 1.0000 - coord_IoU: 0.7779 - classes_accuracy: 0.8383 - val_loss: 0.4202 - val_p_loss: 2.2555e-07 - val_coord_loss: 0.2941 - val_classes_loss: 0.1262 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6160 - val_classes_accuracy: 0.7143
# Epoch 49/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1151 - p_loss: 2.8130e-07 - coord_loss: 0.0394 - classes_loss: 0.0757 - p_accuracy: 1.0000 - coord_IoU: 0.7891 - classes_accuracy: 0.8515 - val_loss: 0.3900 - val_p_loss: 1.4583e-07 - val_coord_loss: 0.2714 - val_classes_loss: 0.1186 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6202 - val_classes_accuracy: 0.7476
# Epoch 50/50
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1101 - p_loss: 2.8104e-07 - coord_loss: 0.0378 - classes_loss: 0.0722 - p_accuracy: 1.0000 - coord_IoU: 0.7886 - classes_accuracy: 0.8627 - val_loss: 0.4161 - val_p_loss: 1.3691e-07 - val_coord_loss: 0.2932 - val_classes_loss: 0.1228 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6067 - val_classes_accuracy: 0.7048

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_IoU')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)


class_res, accuracy = global_accuracy(y_test, y_pred, iou_thres=0.4)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("------------------------------------------")
# Out:
# 8/8 [==============================] - 0s 4ms/step
# <ipython-input-18-e2d735190f54>:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_pred[i, 0] = y_pred_presence[i]
# La précision globale est de 53.6%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.21    |  0.14  |   0.17   |
# ------------------------------------------
# | VEREUR |   0.70    |  0.73  |   0.71   |
# ------------------------------------------
# | ECUROU |   0.91    |  0.91  |   0.91   |
# ------------------------------------------
# | PIEBAV |   0.87    |  0.91  |   0.89   |
# ------------------------------------------
# | SITTOR |   0.29    |  0.32  |   0.30   |
# ------------------------------------------
# | PINARB |   0.62    |  0.73  |   0.67   |
# ------------------------------------------
# | MESNOI |   0.26    |  0.36  |   0.30   |
# ------------------------------------------
# | MESNON |   0.47    |  0.36  |   0.41   |
# ------------------------------------------
# | MESBLE |   0.14    |  0.14  |   0.14   |
# ------------------------------------------
# | ROUGOR |   0.72    |  0.62  |   0.67   |
# ------------------------------------------
# | ACCMOU |   0.56    |  0.64  |   0.60   |
# ------------------------------------------

# %% [markdown]
# Compte-tenu de la taille réduite de la base de données, les résultats ne sont pas mal du tout ! On observe quelques confusions entre certaines classes mais les prédictions sont souvent intéressantes.
#
# Il devrait cependant subsister un fort surapprentissage à ce stade. Comme nous l'avons vu dans de précédents TPs, vous avez plusieurs possibilités qui s'offrent à vous pour le corriger :
#
# *   Augmentation de la base de données. Vous pouvez pour cela vous appuyer sur l'exemple fourni en TP précédent, avec une classe *Sequence* et l'utilisation de la librairie *Albumentation*. Je vous fournis une Sequence qui fonctionne ci-dessous.
# *   Utilisation de *transfer learning* : partant d'un réseau entraîné sur ImageNet (qui contient de nombreuses classes d'animaux), vous bénéficieriez de filtres très généraux qui aiderait à limiter le surapprentissage.

# %% [markdown]
# # Code fourni pour vous aider à mettre en place l'augmentation de données

# %% [markdown]
# Définition des augmentations

# %%
import cv2 as cv
from albumentations import (Compose, RandomBrightnessContrast, HorizontalFlip)
import albumentations as A

AUGMENTATIONS_TRAIN = Compose([
    HorizontalFlip(),
    RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5)
], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels']))

# %% [markdown]
# Une sequence qui permet d'implanter l'augmentation de données :

# %%
from tensorflow.keras.utils import Sequence

class MangeoireSequence(Sequence):
    # Initialisation de la séquence avec différents paramètres
    def __init__(self, x_set, y_set, batch_size,augmentations):
        self.x, self.y = x_set, y_set
        self.classes = ['MESCHA', 'VEREUR', 'ECUROU', 'PIEBAV', 'SITTOR', 'PINARB', 'MESNOI', 'MESNON', 'MESBLE', 'ROUGOR', 'ACCMOU']
        self.batch_size = batch_size
        self.augment = augmentations
        self.indices1 = np.arange(x_set.shape[0])
        np.random.shuffle(self.indices1) # Les indices permettent d'accéder
        # aux données et sont randomisés à chaque epoch pour varier la composition
        # des batches au cours de l'entraînement

    # Fonction calculant le nombre de pas de descente du gradient par epoch
    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    # Il y a des problèmes d'arrondi dans les conversions de boîtes englobantes
    # internes à la librairie Albumentations
    # Pour les contourner, si les boîtes sont trop proches des bords, on les érode un peu
    def erode_bounding_box(self, box):
        epsilon = 0.01

        xmin = max(box[0] - box[2]/2, epsilon)
        ymin = max(box[1] - box[3]/2, epsilon)
        xmax = min(box[0] + box[2]/2, 1-epsilon)
        ymax = min(box[1] + box[3]/2, 1-epsilon)

        cx = xmin + (xmax - xmin)/2
        cy = ymin + (ymax - ymin)/2
        width = xmax - xmin
        height = ymax - ymin

        return np.array([cx, cy, width, height])

    # Application de l'augmentation de données à chaque image du batch et aux
    # boîtes englobantes associées
    def apply_augmentation(self, bx, by):

        batch_x = np.zeros((bx.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
        batch_y = by

        # Pour chaque image du batch
        for i in range(len(bx)):
            bboxes = []
            box = by[i,1:5]
            # Dénormalisation des coordonnées de boites englobantes
            box[0] = (box[0]*y_std[1] + y_mean[1])
            box[1] = (box[1]*y_std[2] + y_mean[2])
            box[2] = (box[2]*y_std[3] + y_mean[3])
            box[3] = (box[3]*y_std[4] + y_mean[4])
            box = self.erode_bounding_box(box)
            bboxes.append(box)

            class_labels = []
            class_id = np.argmax(by[i, 5:])
            class_labels.append(self.classes[class_id])

            img = bx[i].astype('float32')

            # Application de l'augmentation à l'image et aux masques
            transformed = self.augment(image=img.astype('float32'), bboxes=bboxes, class_labels=class_labels)
            batch_x[i] = transformed['image']
            batch_y_transformed = transformed['bboxes']

            # Renormalisation des coordonnées de boîte englobante transformée
            batch_y[i, 1] = (batch_y_transformed[0][0] - y_mean[1])/y_std[1]
            batch_y[i, 2] = (batch_y_transformed[0][1] - y_mean[2])/y_std[2]
            batch_y[i, 3] = (batch_y_transformed[0][2] - y_mean[3])/y_std[3]
            batch_y[i, 4] = (batch_y_transformed[0][3] - y_mean[4])/y_std[4]

        return batch_x, batch_y

    # Fonction appelée à chaque nouveau batch : sélection et augmentation des données
    def __getitem__(self, idx):
        batch_x = self.x[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_y = self.y[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_x, batch_y = self.apply_augmentation(batch_x, batch_y)

        batch_y = np.array(batch_y)
        return np.array(batch_x), [batch_y[:,0], batch_y[:,1:5], batch_y[:,5:]]

    # Fonction appelée à la fin d'un epoch ; on randomise les indices d'accès aux données
    def on_epoch_end(self):
        np.random.shuffle(self.indices1)

# %%
# Instanciation d'une Sequence
train_gen = MangeoireSequence(x_train, y_train, 16, augmentations=AUGMENTATIONS_TRAIN)

# Pour tester la séquence, nous sélectionnons les éléments du premier batch et les affichons
batch_x, batch_y = train_gen.__getitem__(0)

y_batch = np.zeros((batch_y[0].shape[0],1+4+num_classes))

for i in range(batch_y[0].shape[0]):
  y_batch[i, 0] = batch_y[0][i]
  y_batch[i, 1:5] = batch_y[1][i]
  y_batch[i, 5:] = batch_y[2][i]

print_data_localisation(batch_x, y_batch, image_size=IMAGE_SIZE)
